# %%
import numpy as np
import pandas as pd
df = pd.read_csv("C:\\Mlops Day 1\\Data\\data.csv")  
df.head()
# Out:
# Running cells with 'Mlops_Day1_env (Python 3.13.15)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Mlops Day 1\Mlops_Day1_env ipykernel --update-deps --force-reinstall'
